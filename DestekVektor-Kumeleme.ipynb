# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
veri1=pd.read_csv('/content/musteri.csv')

# %%
veri1.head()

# %%
olcekle = StandardScaler()
pca = PCA(n_components=2)

onIslem = make_pipeline(olcekle, pca)

x_onIslem = onIslem.fit_transform(veri1)

# %%
x_onIslem

# %%
#DESTEK VEKTOR MAKİNE
#SUPPORT VECTOR MACHINE
svm = SVC(kernel='linear',C=1.0)

# %%
svm.fit(x_onIslem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4100b715dc02> in <cell line: 1>()
# ----> 1 svm.fit(x_onIslem)
#
# TypeError: BaseLibSVM.fit() missing 1 required positional argument: 'y'
